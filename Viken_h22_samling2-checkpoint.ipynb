# %% [markdown]
# # Programmering i fag
# ### 04.11.22 - Samling 2

# %% [markdown]
# ## Oversikt
#
# - Flytskjema
# - while-løkker
# - plotting
#
# ### 4 Oppgaver:
# - Flytskjema
# - Gjettelek
# - Vekstfaktor
# - Funksjonsplotting

# %% [markdown]
# ## Flytskjema

# %% [markdown]
# ![flooow.PNG](attachment:flooow.PNG)

# %% [markdown]
# <div class="alert alert-success">
#
# ## Oppgave 1: Flytskjema
#
# Lag et flytskjema til oppgaven under.
#
#
# Skriv et program som summerer to tilfeldig-genererte tall mellom 1-5 (ved hjelp av random-biblioteket).
# Spør brukeren hva hen tror summen av de to tallene blir.
#
# Programmet gir dermed beskjed om brukeren gjettet riktig eller feil.
#
#
# Nettside for å lage flytskjema: https://www.diagrams.net/
#
# </div>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## OPPGAVE 2 a): Gjettelek
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <div class="alert alert-success">
#
# **SORT BELTE:**
#
#
# **Oppgave:** Skriv et program hvor det trekkes et tilfeldig tall fra 1 – 5, hvor brukeren blir spurt om å gjette hva tallet er. Dersom brukeren gjetter feil, får brukeren gjette på nytt. Programmet er ikke ferdig før brukeren har gjettet riktig!
#
# </div>

# %%
# Gjettelek - sort belte

# Gjettelek - skjelettkode

from random import randint

hemmelig_tall = 2
gjett = int(input("5"))
antall_gjett = 2

while hemmelig_tall<5: 
    
    if ???: 
        gjett = int(input("???"))
    else: 
        gjett = int(input("???"))
    
    antall_gjett = ???

print("Hurra, du gjettet riktig! Du gjettet totalt", ???, "ganger.")

# %% [markdown]
# <div class="alert alert-success">
#
# **LILLA BELTE:** Hint: For å løse oppgaven trenger du:
#
# - variabler​
#
# - randint() - funksjonen​
#
# - input() - funksjonen​
#
# - while - løkke
#
# </div>

# %%
# Gjettelek - lilla belte

# %% [markdown]
# <div class="alert alert-success">
#
#
# **BLÅTT BELTE:** Flytskjema
#
#
# </div>

# %% [markdown]
# ![gjettelek.PNG](attachment:gjettelek.PNG)

# %% [markdown]
# <div class="alert alert-success">
#
# **GULT BELTE** - Skjelettkode
#
# Se skjelettkode under.
# Bytt ut spørsmålstegnene ??? for å fullføre programmet.
#
# Link til trinket med skjelettkode: https://trinket.io/python3/56ff4a223c
# </div>

# %% [markdown]
# Link til gjettelek fasit: https://trinket.io/python3/3173030046

# %% [markdown]
# ## OPPGAVE 2 b) Gjettelk - utvidelse

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-success">
#
# **SORT BELTE** - Oppgavetekst
#
# **Oppgave:** Utvid gjettelek-programmet slik at brukeren får beskjed om hen gjettet for høyt eller for lavt dersom gjettet er feil.
#
# I tillegg skal programmet telle antall ganger brukeren brukte på å gjette det hemmelige tallet.
#
# </div>

# %%
# Gjettelek utvidelse

# %% [markdown]
# <div class="alert alert-success">
#
# **LILLA BELTE** - Programmerings-hint
#
# For å løse oppgaven trenger du:
#
# - Tellevariabel
# - If-test
#
# </div>

# %%
# Gjetteek - utvidelse

# %% [markdown]
# <div class="alert alert-success">
#
# **BLÅTT BELTE** - Flytskjema
#
# </div>

# %% [markdown]
# ![gjettelek_utvidelse.PNG](attachment:gjettelek_utvidelse.PNG)

# %%
# Gjettelek - utvidelse

# %% [markdown]
# <div class="alert alert-success">
#
# **GULT BELTE** - Skjelettkode
# Bytt ut spørsmålstegnene ??? for å fullføre programmet.
#
#
# Link til skjelettkode: https://trinket.io/python3/5c2e946b45
#
#
#
# </div>

# %% [markdown]
# Fasit gjettelek utvidelse: https://trinket.io/python3/962ec2cc82

# %% [markdown]
# # OPPGAVE 3 - Vekstfaktor

# %% [markdown]
# ![azorene.PNG](attachment:azorene.PNG)

# %% [markdown]
# <div class="alert alert-success">
#
# **SORT BELTE** - Oppgavetekst
#
#
# **Oppgave:**  Skriv et program som regner ut hvor mange år du må spare penger i banken, så du har råd til ferietur til Azorene med budsjett på 30.000 kr når du får 2.7 % rente. Initialbeløpet ditt er 5000 kr.​
# </div>

# %%
# Vekstfaktor

# %% [markdown]
# <div class="alert alert-success">
#
# **LILLA BELTE** - Hint
#
# For å løse oppgaven trenger du å bruke:
#
# - variabler​
#
# - while – løkke​
#
# - matematiske operatorer
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# **BLÅTT BELTE** - Flytskjema
#
# </div>

# %% [markdown]
# ![azorene_fly.PNG](attachment:azorene_fly.PNG)

# %%
#Terningkast - blått belte

# %% [markdown]
# <div class="alert alert-success">
#
# **GULT BELTE** - Skjelettkode
#
# Bytt ut spørsmålstegnene ??? for å fullføre programmet.
#
# Link til skjelettkode: https://trinket.io/python3/2e6e2ca294
#
#
# </div>

# %% [markdown]
# Fasit vekstfaktor: https://trinket.io/python3/d9a0fe703d

# %% [markdown]
# ## Oppgave 4: Plotte funksjoner
#
# ![image.png](attachment:image.png)
#
# Vi skal nå plotte enkle funksjoner.
# Her bruker vi bibliotekene `numpy` og `matplotlib.pyplot`

# %% [markdown]
# <div class="alert alert-success">
#
# **SORT BELTE** - Oppgavetekst
#
# **Oppgave:**
#     a) Plott en valgfri funksjon ved bruk av linspace - funksjonen fra numpy og plot - funksjonen fra matplotlib.pyplot.
#     b) Endre parametrene i linspace - funksjonen og beskriv hva du observerer når disse endres.
#     c) Plott to ulike funksjoner i samme plott. Eksempelvis kan du plotte en funksjon og dens deriverte.
#
# </div>

# %%
# Plotte funksjoner - sort belte

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <div class="alert alert-success">
#
# **LILLA BELTE** - Hint
#
# For å løse oppgaven må du opprette to variabler (eks. x og y) som plottes mot hverandre.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# **GULT BELTE** - Skjelettkode
#
# Se skjelettkode under.
# Bytt ut spørsmålstegnene ??? for å fullføre programmet.
#
# </div>

# %%
# Plotte funksjoner - skjelettkode


import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(???,???,???)   # Undersøk hva parametrene i denne funksjonen gjør
y = ???????????

plt.plot(???,???)
# Out:
#   Input In [7]
#     x = np.linspace(???,???,???)   # Undersøk hva parametrene i denne funksjonen gjør
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Noen vanlige plotte-kommandoer
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Takk for i dag!
# ![Picture1.jpg](attachment:Picture1.jpg)

# %% [markdown]
# <div class="alert alert-success">
#
#
# </div>
